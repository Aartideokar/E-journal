# %% [markdown]
# ### Models of Time Series-
#
# 1. Auto-Regressive Models(AR Model)
# 2. Auto Regressive Moving Average Model(ARMA)
# 3. Auto Regressive Integrated Moving Average Model(ARIMA)
# 4. Seasonal Auto-Regressive Integrated Moving Average Model(SARIMA)

# %%
import numpy as np
import pandas as pd

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
sales = np.array([200,290,280,300,220])
sales
# Out:
# array([200, 290, 280, 300, 220])

# %%
plot_acf(sales)
